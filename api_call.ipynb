# %%
import requests
import pandas
import time
import json
from getpass import getpass

# %%
#keys 
api_key = 'QtpP6VDdEWbMP7FkAE7FHhxfieseAr2JwB69GuUY'
state_codes = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA', 
    'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 
    'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 
    'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']
crimes = ['aggravated-assault', 'burglary', 'larceny','motor-vehicle-theft', 'homicide', 'rape', 'robbery', 'arson', 'violent-crime', 'property-crime' ]
start_year = 2020
end_year = 2020

# %%
#make api call
crime_data = {}
response_list=[]
base_url = 'https://api.usa.gov/crime/fbi/sapi/'
for crime in crimes:
    for state_code in state_codes:
        url = base_url+f'/api/summarized/state/{state_code.lower()}/{crime}/{start_year}/{end_year}?API_KEY={api_key}'
        response = requests.get(url).json()
        response_list+=response['results']
    crime_data[crime]=response_list
    response_list = []

# %%
crime_data
# Out:
# {'aggravated-assault': [{'ori': 'AL0010000',
#    'data_year': 2020,
#    'offense': 'aggravated-assault',
#    'state_abbr': 'AL',
#    'cleared': 76,
#    'actual': 218,
#    'data_range': None},
#   {'ori': 'AL0010100',
#    'data_year': 2020,
#    'offense': 'aggravated-assault',
#    'state_abbr': 'AL',
#    'cleared': 1,
#    'actual': 374,
#    'data_range': None},
#   {'ori': 'AL0010200',
#    'data_year': 2020,
#    'offense': 'aggravated-assault',
#    'state_abbr': 'AL',
#    'cleared': 181,
#    'actual': 651,
#    'data_range': None},
#   {'ori': 'AL0010400',
#    'data_year': 2020,
#    'offense': 'aggravated-assault',
#    'state_abbr': 'AL',
#    'cleared': 0,
#    'actual': 1,
#    'data_range': None},
#   {'ori': 'AL0010600',
#    'data_year': 2020,
#    'offense': 'aggravated-assault',
#    'state_abbr': 'AL',
#    'cleared': 2,
#    'actual': 31,
#    'data_range': None},
#   {'ori': 'AL0010700',
#    'data_year': 2020,
#    'offense': 'aggravated-assault',
# ...

# %%
crime_data = {}
crime_data['violent-crime'] = json_obj

# %%
crime_data
# Out:
# {'violent-crime': [{'ori': 'AL0010000',
#    'data_year': 2019,
#    'offense': 'violent-crime',
#    'state_abbr': 'AL',
#    'cleared': 62,
#    'actual': 209,
#    'data_range': None},
#   {'ori': 'AL0010100',
#    'data_year': 2019,
#    'offense': 'violent-crime',
#    'state_abbr': 'AL',
#    'cleared': 3,
#    'actual': 383,
#    'data_range': None},
#   {'ori': 'AL0010300',
#    'data_year': 2019,
#    'offense': 'violent-crime',
#    'state_abbr': 'AL',
#    'cleared': 0,
#    'actual': 0,
#    'data_range': None},
#   {'ori': 'AL0010400',
#    'data_year': 2019,
#    'offense': 'violent-crime',
#    'state_abbr': 'AL',
#    'cleared': 18,
#    'actual': 122,
#    'data_range': None},
#   {'ori': 'AL0010500',
#    'data_year': 2019,
#    'offense': 'violent-crime',
#    'state_abbr': 'AL',
#    'cleared': 1,
#    'actual': 2,
#    'data_range': None},
#   {'ori': 'AL0010600',
#    'data_year': 2019,
#    'offense': 'violent-crime',
#    'state_abbr': 'AL',
# ...
